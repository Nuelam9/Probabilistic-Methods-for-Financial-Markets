# %%
#!/usr/bin/env python3.10.4
import sys
sys.path.append('../lib/')
from functions import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = '../Data/'
years = [2021, 2022]

dfs = []
for year in years:
    file_name = f'daily-treasury-rates_{year}.csv'
    df = read_gold_data(file_path + file_name)
    dfs.append(df)

# %%
dfs[0]
# Out:
#           Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 0   2021-01-04  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1   2021-01-05  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2   2021-01-06  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3   2021-01-07  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4   2021-01-08  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 246 2021-12-27  0.04  0.05  0.06  0.21  0.33  0.76  0.98  1.26  1.41   1.48
# 247 2021-12-28  0.03  0.04  0.06  0.20  0.39  0.74  0.99  1.27  1.41   1.49
# 248 2021-12-29  0.01  0.02  0.05  0.19  0.38  0.75  0.99  1.29  1.47   1.55
# 249 2021-12-30  0.06  0.06  0.05  0.19  0.38  0.73  0.98  1.27  1.44   1.52
# 250 2021-12-31  0.06  0.05  0.06  0.19  0.39  0.73  0.97  1.26  1.44   1.52
#
#      20 Yr  30 Yr
# 0     1.46   1.66
# ...

# %%
dfs[1]
# Out:
#          Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 0  2022-01-03  0.05  0.06  0.08  0.22  0.40  0.78  1.04  1.37  1.55   1.63
# 1  2022-01-04  0.06  0.05  0.08  0.22  0.38  0.77  1.02  1.37  1.57   1.66
# 2  2022-01-05  0.05  0.06  0.09  0.22  0.41  0.83  1.10  1.43  1.62   1.71
# 3  2022-01-06  0.04  0.05  0.10  0.23  0.45  0.88  1.15  1.47  1.66   1.73
# 4  2022-01-07  0.05  0.05  0.10  0.24  0.43  0.87  1.17  1.50  1.69   1.76
# ..        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 75 2022-04-21  0.50  0.65  0.83  1.32  2.01  2.68  2.87  2.96  2.96   2.90
# 76 2022-04-22  0.46  0.64  0.83  1.34  2.06  2.72  2.88  2.94  2.95   2.90
# 77 2022-04-25  0.40  0.61  0.91  1.42  2.03  2.63  2.79  2.84  2.85   2.81
# 78 2022-04-26  0.38  0.61  0.83  1.40  1.99  2.54  2.72  2.79  2.80   2.77
# 79 2022-04-27  0.37  0.63  0.82  1.39  1.97  2.58  2.75  2.81  2.84   2.82
#
#     20 Yr  30 Yr
# 0    2.05   2.01
# 1    2.10   2.07
# ...

# %%
plot_yield_rates(df=dfs[0], start_day='2021-04-01', end_day='2021-04-18')

# %%
plot_yield_rates(df=dfs[1], start_day='2022-04-01', end_day='2022-04-18')

# %%
# other link: https://www.treasurydirect.gov/GA-FI/FedInvest/selectSecurityPriceDate
