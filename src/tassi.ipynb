# %%
#!/usr/bin/env python3.10.4
import sys
sys.path.append('../lib/')
from functions import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = '../Data/'
years = [2021, 2022]

dfs = []
for year in years:
    file_name = f'daily-treasury-rates_{year}.csv'
    df = read_gold_data(file_path + file_name)
    df.Date = pd.to_datetime(df.Date, format='%d/%m/%Y')
    dfs.append(df)

# %%
dfs[0]
# Out:
#           Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 0   2021-01-04  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1   2021-01-05  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2   2021-01-06  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3   2021-01-07  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4   2021-01-08  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 246 2021-12-27  0.04  0.05  0.06  0.21  0.33  0.76  0.98  1.26  1.41   1.48
# 247 2021-12-28  0.03  0.04  0.06  0.20  0.39  0.74  0.99  1.27  1.41   1.49
# 248 2021-12-29  0.01  0.02  0.05  0.19  0.38  0.75  0.99  1.29  1.47   1.55
# 249 2021-12-30  0.06  0.06  0.05  0.19  0.38  0.73  0.98  1.27  1.44   1.52
# 250 2021-12-31  0.06  0.05  0.06  0.19  0.39  0.73  0.97  1.26  1.44   1.52
#
#      20 Yr  30 Yr
# 0     1.46   1.66
# 1     1.49   1.70
# 2     1.60   1.81
# 3     1.64   1.85
# 4     1.67   1.87
# ..     ...    ...
# 246   1.92   1.88
# 247   1.94   1.90
# 248   2.00   1.96
# 249   1.97   1.93
# 250   1.94   1.90
#
# [251 rows x 13 columns]

# %%
dfs[0][(dfs[0].Date <= '18/04/2021') & (dfs[0].Date >= '04/04/2021')]
# Out:
#          Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 63 2021-04-05  0.03  0.02  0.03  0.04  0.06  0.17  0.37  0.94  1.40   1.73
# 64 2021-04-06  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.88  1.34   1.67
# 65 2021-04-07  0.01  0.02  0.02  0.04  0.06  0.16  0.34  0.87  1.34   1.68
# 66 2021-04-08  0.02  0.02  0.01  0.04  0.05  0.14  0.33  0.85  1.30   1.64
# 67 2021-04-09  0.02  0.01  0.02  0.03  0.06  0.16  0.35  0.87  1.33   1.67
# 68 2021-04-12  0.02  0.02  0.02  0.04  0.06  0.18  0.38  0.89  1.35   1.69
# 69 2021-04-13  0.03  0.02  0.03  0.05  0.06  0.16  0.35  0.85  1.29   1.64
# 70 2021-04-14  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.87  1.31   1.64
# 71 2021-04-15  0.02  0.01  0.02  0.04  0.06  0.16  0.32  0.81  1.24   1.56
# 72 2021-04-16  0.02  0.02  0.02  0.04  0.06  0.16  0.34  0.84  1.26   1.59
#
#     20 Yr  30 Yr
# 63   2.28   2.36
# 64   2.24   2.32
# 65   2.26   2.35
# 66   2.22   2.32
# 67   2.23   2.34
# 68   2.24   2.34
# 69   2.21   2.32
# 70   2.22   2.32
# 71   2.13   2.23
# 72   2.15   2.26

# %%
tmp = dfs[0][(dfs[0].Date <= '18/04/2021') & (dfs[0].Date >= '04/04/2021')].transpose()

tmp.columns = tmp.loc['Date']

fig, ax = plt.subplots(figsize=(15, 9))
tmp.iloc[1:, :].plot(ax=ax, grid=True)
#plt.suptitle("University of Roma \"Tor Vergata\" - Corso di Metodi"
#            + " Probabilistici e Statistici per i Mercati Finanziari \n"
#            + f" Line plots U.S. Treasury Yield Curve Rates" 
#            + f" {title} from {first_day} to {last_day}")
#plt.title(f"Path length {n} sample points. Data from Yahoo Finance " 
#            + f"{symbol} - {link}")
plt.xlabel('time to maturity')
plt.ylabel('yield rates')
# Out:
# Text(0, 0.5, 'yield rates')

# %%
dfs[1][(dfs[1].Date <= '18/04/2022') & (dfs[1].Date >= '04/04/2022')]
# Out:
#          Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 63 2022-04-04  0.18  0.42  0.66  1.14  1.72  2.43  2.61  2.56  2.52   2.42
# 64 2022-04-05  0.18  0.42  0.65  1.13  1.77  2.51  2.69  2.69  2.65   2.54
# 65 2022-04-06  0.21  0.44  0.67  1.15  1.79  2.50  2.67  2.70  2.69   2.61
# 66 2022-04-07  0.21  0.50  0.68  1.15  1.78  2.47  2.66  2.70  2.73   2.66
# 67 2022-04-08  0.20  0.49  0.70  1.19  1.81  2.53  2.73  2.76  2.79   2.72
# 68 2022-04-11  0.22  0.54  0.77  1.23  1.85  2.50  2.73  2.79  2.84   2.79
# 69 2022-04-12  0.21  0.52  0.74  1.20  1.77  2.39  2.58  2.66  2.73   2.72
# 70 2022-04-13  0.26  0.52  0.75  1.20  1.78  2.37  2.57  2.66  2.71   2.70
# 71 2022-04-14  0.37  0.57  0.79  1.25  1.84  2.47  2.67  2.79  2.84   2.83
# 72 2022-04-18  0.38  0.60  0.81  1.27  1.84  2.46  2.68  2.79  2.85   2.85
#
#     20 Yr  30 Yr
# 63   2.64   2.48
# 64   2.74   2.57
# 65   2.81   2.63
# 66   2.87   2.69
# 67   2.94   2.76
# 68   3.02   2.84
# 69   2.99   2.82
# 70   2.97   2.81
# 71   3.09   2.92
# 72   3.12   2.95

# %%
tmp = dfs[1][(dfs[1].Date <= '18/04/2022') & (dfs[1].Date >= '04/04/2022')].transpose()

tmp.columns = tmp.loc['Date']

fig, ax = plt.subplots(figsize=(15, 9))
tmp.iloc[1:, :].plot(ax=ax, grid=True)
#plt.suptitle("University of Roma \"Tor Vergata\" - Corso di Metodi"
#            + " Probabilistici e Statistici per i Mercati Finanziari \n"
#            + f" Line plots U.S. Treasury Yield Curve Rates" 
#            + f" {title} from {first_day} to {last_day}")
#plt.title(f"Path length {n} sample points. Data from Yahoo Finance " 
#            + f"{symbol} - {link}")
plt.xlabel('time to maturity')
plt.ylabel('yield rates')
# Out:
# Text(0, 0.5, 'yield rates')

# %%
# other link: https://www.treasurydirect.gov/GA-FI/FedInvest/selectSecurityPriceDate
